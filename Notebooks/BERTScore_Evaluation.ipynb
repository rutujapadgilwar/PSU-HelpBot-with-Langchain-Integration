# %%
# !pip install sacrebleu

# %%
import pandas as pd
from transformers import BertTokenizer, BertForMaskedLM
from sacrebleu import BLEU

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/Courses/LLM Project/testData.csv')

# %%
data
# Out:
#                                              Question  \
# 0   By what date should graduate students submit t...
# 1                           Do PSU offere LLM course?
# 2     Date of Degree Conferral (Fall 2023 Graduates)?
# 3   Can you provide me contact details of graduate...
# 4   When is the deadline for submitting the Master...
# 5   By what date should graduate students submit t...
# 6   By what date should graduate students submit t...
# 7   On what date will the degrees be conferred for...
# 8   When does the degree awarding process begin fo...
# 9   What is the deadline for submitting the Master...
# 10  What is the deadline for the MSCS graduation a...
# 11       What are the compulsory classes for AI track
# 12  What are the compulsory classes for security t...
# 13  What are the compulsory classes for database t...
# 14  What are the compulsory classes for systems an...
# 15  What are the compulsory classes for languages ...
# ...

# %% [markdown]
# ### Evaluation with GPT-3.5-Turbo_Similarity_Search

# %%
reference  = data['True_Answers']
predictions = data['GPT-3.5_turbo-Search_type_QARetrieval']

# %%
# !pip install evaluate

# %%
# !pip install bert_score

# %%
from evaluate import load
bertscore = load("bertscore")
results = bertscore.compute(predictions=predictions, references=reference, lang="en")

# %%
results

# %%
precision_scores = results['precision']
recall_scores = results['recall']
f1_scores = results['f1']

# Calculate the mean of precision, recall, and F1 scores
mean_precision = sum(precision_scores) / len(precision_scores)
mean_recall = sum(recall_scores) / len(recall_scores)
mean_f1 = sum(f1_scores) / len(f1_scores)

print("Mean Precision:", mean_precision)
print("Mean Recall:", mean_recall)
print("Mean F1 Score:", mean_f1)
# Out:
# Mean Precision: 0.845502178279721
# Mean Recall: 0.8796122694502071
# Mean F1 Score: 0.8619969316891262

# %% [markdown]
# ### Evaluation with GPT-3.5-Turbo_MMR_Search_Type
#
# ---

# %%
reference  = data['True_Answers']
predictions = data['GPT-3.5-turbo_MMR_Search_type_QARetrieval']

# %%
from evaluate import load
bertscore = load("bertscore")
MMR_Approch_results = bertscore.compute(predictions=predictions, references=reference, lang="en")
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
precision_scores = MMR_Approch_results['precision']
recall_scores = MMR_Approch_results['recall']
f1_scores = MMR_Approch_results['f1']

# Calculate the mean of precision, recall, and F1 scores
mean_precision = sum(precision_scores) / len(precision_scores)
mean_recall = sum(recall_scores) / len(recall_scores)
mean_f1 = sum(f1_scores) / len(f1_scores)

print("Mean Precision:", mean_precision)
print("Mean Recall:", mean_recall)
print("Mean F1 Score:", mean_f1)
# Out:
# Mean Precision: 0.8496242214222344
# Mean Recall: 0.8813968118356199
# Mean F1 Score: 0.8648401669093541

# %% [markdown]
# ## Evaluation with Davinci-002

# %%
reference  = data['True_Answers']
predictions = data['davinci-002']

# %%
from evaluate import load
bertscore = load("bertscore")
Davinci_result = bertscore.compute(predictions=predictions, references=reference, lang="en")

# %%
precision_scores = Davinci_result['precision']
recall_scores = Davinci_result['recall']
f1_scores = Davinci_result['f1']

# Calculate the mean of precision, recall, and F1 scores
mean_precision = sum(precision_scores) / len(precision_scores)
mean_recall = sum(recall_scores) / len(recall_scores)
mean_f1 = sum(f1_scores) / len(f1_scores)

print("Mean Precision:", mean_precision)
print("Mean Recall:", mean_recall)
print("Mean F1 Score:", mean_f1)
# Out:
# Mean Precision: 0.8682680628737625
# Mean Recall: 0.8808050824671375
# Mean F1 Score: 0.874012158841503

# %% [markdown]
# ### Evaluation with GPT-3.5-turbo without RAG

# %%
reference  = data['True_Answers']
predictions = data['GPT-3.5-turbo_without data']

# %%
from evaluate import load
bertscore = load("bertscore")
GPT_result = bertscore.compute(predictions=predictions, references=reference, lang="en")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
precision_scores = GPT_result['precision']
recall_scores = GPT_result['recall']
f1_scores = GPT_result['f1']

# Calculate the mean of precision, recall, and F1 scores
mean_precision = sum(precision_scores) / len(precision_scores)
mean_recall = sum(recall_scores) / len(recall_scores)
mean_f1 = sum(f1_scores) / len(f1_scores)

print("Mean Precision:", mean_precision)
print("Mean Recall:", mean_recall)
print("Mean F1 Score:", mean_f1)
# Out:
# Mean Precision: 0.80294425755131
# Mean Recall: 0.8485119245490249
# Mean F1 Score: 0.8248053947273566
